# %% [markdown]
# <a href="https://colab.research.google.com/github/theakash07/Computer-Vision/blob/main/ComputerVisionLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Computer VIsion**
#
# Introduction
#
# --------------------------------------------------------------------------------
#
# 1. OpenCv is image Processing Library created by INtel and later supported by willow garage and maintained by itseez
#
# 2. OpenSource and Free

# %% [markdown]
# I'm performing all the Codes in Google Collab as it doesn't support all the things smoothly so maybe you will encounter something different. Buh don't worry about it.
#
# I'll do the proper Documentation of the Codes

# %% [markdown]
#    Image vs Matrix
# -------------------------------------------------------------------------------
# 1. Digitals images are typically stored in a matrix !
# 2. There are numerous file formats of images.

# %% [markdown]
# How do computer see Images:
#  1. They see it in two different way.
#
#      a. **Grayscale** 🦜
#
#      b. **Colored.** 🍀
#
#  2. In grayscale, Each Pixel represents the intensity of only one shade.
#      that means how bright and dark the pixel is.
#
#  3. Grayscale Images have One channel.
#
#  4. Grayscale intensity range from (0, 255).
#
#  5. Computers interpret grayscale images by analyzing these intensity values
#       without considering color information.
# ---------------------------------------------------------------------------
#
#  ◀**Colored Images**▶  ⛹
#
# 1. Color images are more complex. They consist of **3 channel** Red, Blue and Green  ( Commonly known as RGB).
#
# 2. Each pixel in an RGB image has three intensity values, one for each channel.
#
# 3. Computer Processes the color of images by considering the combination of
#   these 3 channel.

# %%
print(cv2.__version__)#printing the version of Cv
# Out:
# 4.8.0

# %%
import cv2 #importign Cv library
from google.colab.patches import cv2_imshow

# %%
#Connecting my google drive where i'm stroing the data so that i fetch easily.
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ⚾ Code to read a Image in OpenCv ♒
#
# -----------------------------------------------
# 1. imread is used to read the intesity of the image.
#
# 2. The first argument imread takes the image name.
#
# 3. The second the argument is the flag and there are three flags
#
#     either -1 , 0 ,1 .
#     The second argument specifies the way images should be read.
# --------------------------------------------------------------------------
#
#   ⚡**image read mode** ⚡
#
#         using 1 shows the colored Image.
#         using 0 shows the grayscale images.
#         usign -1 shows the image including alpha channel.
#
# * If the image has no alpha channel (e.g., JPEG), it reads the image as a 3-channel BGR image (Blue, Green, Red).
#
# * If the image has an alpha channel (e.g., PNG or TIFF), it reads the image as a 4-channel BGRA image (Blue, Green, Red, Alpha).
#
# * The **alpha channel** represents **transparency** in an image. ⭕

# %%
img =cv2.imread('/content/drive/MyDrive/pexels-mali-maeder-102104.jpg',0)

# %%
print(img) #you can see printing img gives output of all the intensity level of pixels.
# Out:
# [[[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
#  cv2_imshow is used to display image ⛳

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=2827x2827>

# %% [markdown]
# Below codes to Write a image to a file.
# -------------------------------------------
# I'm using GC so i have to give the path of the drive in order to write the image

# %%
cv2.imwrite('/content/apple_copy.jpg', img)
# Out:
# True
